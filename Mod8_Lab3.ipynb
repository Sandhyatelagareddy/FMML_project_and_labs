# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandhyatelagareddy/FMML_project_and_labs/blob/main/Mod8_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 14:38:05--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  79.9MB/s    in 0.9s
#
# 2024-03-31 14:38:06 (79.9 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 21813   0808.2241v1  We construct a framework for studying clusteri...  stat
# 35772   1204.3529v3  We study the hardness of approximation of clau...    cs
# 22768  1706.02492v1  We consider stationary autoregressive processe...  stat
# 24881   1412.5758v4  We present a domain adaption framework to addr...    cs
# 21972   1112.3827v1  This paper is devoted to regret lower bounds i...  stat
# ...             ...                                                ...   ...
# 3548   1711.09482v2  The practical impact of deep learning on compl...  stat
# 27617  1704.00848v1  Automatic cell image segmentation methods in c...    cs
# 25400  1508.04843v1  Efforts to automate the reconstruction of neur...    cs
# 22431  1606.08549v1  Approximate Bayesian Computation (ABC) is a fr...  stat
# 8478   1611.05138v1  Feature pooling layers (e.g., max pooling) in ...    cs
#
#                                                    title  year  \
# 21813  Persistent Clustering and a Theorem of J. Klei...  2008
# 35772  Hardness Results for Approximate Pure Horn CNF...  2012
# 22768  Consistency Results for Stationary Autoregress...  2017
# 24881  Decomposition-Based Domain Adaptation for Real...  2014
# 21972  Regret lower bounds and extended Upper Confide...  2011
# ...                                                  ...   ...
# 3548          An Introduction to Deep Visual Explanation  2017
# 27617  Guided Proofreading of Automatic Segmentations...  2017
# 25400  Recursive Training of 2D-3D Convolutional Netw...  2015
# 22431                          Automatic Variational ABC  2016
# 8478    S3Pool: Pooling with Stochastic Spatial Sampling  2016
#
#                                                 keywords
# 21813  [construct, framework, clustering, algorithms,...
# 35772  [approximation, representations, functions, va...
# 22768  [stationary, autoregressive, processes, coeffi...
# 24881  [framework, synthetic, demonstrate, challengin...
# 21972  [classical, stochastic, katehakis, established...
# ...                                                  ...
# 3548   [practical, supervised, significant, artificia...
# 27617  [automatic, segmentation, connectomics, correc...
# 25400  [reconstruction, microscopic, connectomics, im...
# 22431  [approximate, computation, framework, performi...
# 8478   [convolutional, providing, increasingly, repre...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 21813    [construct, framework, clustering, algorithms,...
# 35772    [approximation, representations, functions, va...
# 22768    [stationary, autoregressive, processes, coeffi...
# 24881    [framework, synthetic, demonstrate, challengin...
# 21972    [classical, stochastic, katehakis, established...
#                                ...
# 11567    [dimensional, structures, efficiency, computat...
# 35400    [artificial, evolutionbased, application, dete...
# 11065    [discriminant, functional, regression, present...
# 24978    [successfully, estimation, explicitly, variabl...
# 19201    [discriminant, detection, modification, percep...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8839 words.
# Out of those 4563 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="81355c0f-2a6a-4091-8dbc-a29219f748a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81355c0f-2a6a-4091-8dbc-a29219f748a6")) {                    Plotly.newPlot(                        "81355c0f-2a6a-4091-8dbc-a29219f748a6",                        [{"x":["persistent","established","functions","analogous","uniqueness","convergence","structure","multiresolution","stability","algorithms","construct","existence","framework","persistence","properties","clustering","functoriality","minimization","variables","polynomial","varepsilon","furthermore","representations","hypothesis","approximation","approximate","exponential","computation","approximations","restricted","consistency","estimators","including","constraint","application","processes","universal","simulations","coefficients","different","penalized","constrained","ellipsoid","estimation","autoregressive","absolutely","stationary","classification","challenging","preprocessed","recognizing","leveraging","effective","recognition","unlabeled","collection","introduce","decomposition","demonstrate","adaptation","collected","technique","convolutional","synthetic","generalization","consistence","classical","generalisation","advantage","consistent","environment","logarithmic","impossible","stochastic","confidence","sequences","intuition","generation","comparison","attributes","distribution","sequentially","generative","variational","conditional","structuring","temporally","uncertainty","generates","evolution","structured","conditioned","appearance","accounting","attribute","experimental","invariant","probabilistic","autoencoders","effectiveness","prediction","generalize","perspective","supervised","entangling","disentangle","inference","variation","interactions","multiplicative","disentangling","objective","boltzmann","regarding","information","expression","parametrized","equivalent","recurrent","recurrence","continuous","dynamical","satisfies","transformations","contribution","interfacing","topological","analytical","continuity","epistemic","presented","requirements","complexity","converges","conjecture","identifying","counterexample","probability","uniformly","approaching","attractive","efficient","regression","predictors","flexibility","developed","separately","relationship","parametric","computational","component","interpretability","scalability","challenge","combination","nonparametric","components","achieving","excellent","simultaneously","importance","simulated","algorithm","dimensions","selection","performance","interaction","decompose","knowledge","considered","promising","retrieval","optimization","propagation","viewpoint","exploited","extensively","constraints","attention","efficiently","subproblems","construction","preparation","automatically","experiments","declarative","languages","relatively","manuscript","implementation","generalizes","configuration","intervention","implement","carefully","constructing","frameworks","cumbersome","technical","differently"],"y":[7,51,228,13,3,132,338,2,35,587,90,28,560,1,198,140,1,69,134,43,2,161,228,57,128,110,35,146,34,35,48,21,257,91,233,90,39,36,24,732,4,72,1,207,9,4,33,514,235,3,37,49,300,366,46,69,365,71,552,68,86,228,368,137,113,1,99,6,91,84,127,13,19,128,40,82,19,126,139,57,196,15,131,64,93,5,20,93,70,69,108,25,70,5,41,385,56,172,21,226,211,52,73,216,1,2,206,64,82,10,5,179,14,35,712,44,6,65,132,5,116,17,13,26,66,2,30,26,9,8,146,53,218,21,6,73,4,186,13,3,21,411,103,12,31,226,37,77,37,274,100,13,36,141,137,12,97,72,30,118,76,66,818,50,158,903,91,17,331,125,87,94,309,71,18,36,30,152,167,146,10,60,5,152,605,14,102,55,8,154,29,25,9,58,37,26,28,8,36,10],"type":"bar"},{"x":["persistent","established","functions","analogous","uniqu ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4563,), (4563, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7975

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>LoIDE</span> <span style=''>a</span> <span style=''>web</span> <span style=''>based</span> <span style=''>IDE</span> <span style=''>for</span> <span style=''>Logic</span> <span style='background-color:rgba(0, 255, 0, 0.3885350318471338);'>Programming</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>Preliminary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Technical</span> <span style=''>Report</span> <br/><br/><span style=''>Logic</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>paradigms</span> <span style=''>are</span> <span style=''>nowadays</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3059768064228368);'>different</span> <span style=''>fields</span> <span style=''>also</span> <span style=''>thank</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4375);'>availability</span> <span style=''>of</span> <span style=''>robust</span> <span style=''>tools</span> <span style=''>and</span> <span style=''>systems</span> <span style=''>that</span> <span style=''>allow</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4597701149425287);'>development</span> <span style=''>of</span> <span style=''>real</span> <span style=''>world</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>industrial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>present</span> <span style=''>LoIDE</span> <span style=''>an</span> <span style=''>advanced</span> <span style=''>and</span> <span style=''>modular</span> <span style=''>web</span> <span style=''>editor</span> <span style=''>for</span> <span style=''>logic</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.9245283018867924);'>languages</span> <span style=''>that</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.441860465116279);'>integrates</span> <span style=''>with</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>solvers</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Dual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Coordinate</span> <span style=''>Ascent</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Alternating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Direction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Multiplier</span> <span style=''>Method</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>dual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coordinate</span> <span style=''>ascent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Alternating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Direction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Multiplier</span> <span style=''>Method</span> <span style=''>(ADMM)</span> <span style=''>to</span> <span style=''>deal</span> <span style=''>with</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularizations</span> <span style=''>Although</span> <span style=''>the</span> <span style=''>original</span> <span style=''>ADMM</span> <span style=''>is</span> <span style=''>a</span> <span style=''>batch</span> <span style=''>method</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>offers</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>update</span> <span style=''>rule</span> <span style=''>where</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iteration</span> <span style=''>requires</span> <span style=''>only</span> <span style=''>one</span> <span style=''>or</span> <span style=''>few</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>Moreover</span> <span style=''>our</span> <span style=''>method</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>naturally</span> <span style=''>afford</span> <span style=''>mini</span> <span style=''>batch</span> <span style=''>update</span> <span style=''>and</span> <span style=''>it</span> <span style=''>gives</span> <span style=''>speed</span> <span style=''>up</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>under</span> <span style=''>mild</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>our</span> <span style=''>method</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converges</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponentially</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style='background-color:rgba(255, 0, 0, 0. ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Convex</span> <span style=''>Coding</span> <br/><br/><span style=''>Inspired</span> <span style=''>by</span> <span style=''>recent</span> <span style=''>work</span> <span style=''>on</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulations</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>(Lashkari</span> <span style=''>Golland</span> <span style=''>2008</span> <span style=''>Nowozin</span> <span style=''>Bakir</span> <span style=''>2008)</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Sparse</span> <span style=''>Coding</span> <span style=''>Problem</span> <span style=''>(Olshausen</span> <span style=''>Field</span> <span style=''>1997)</span> <span style=''>In</span> <span style=''>sparse</span> <span style=''>coding</span> <span style=''>we</span> <span style=''>attempt</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style='background-color:rgba(0, 255, 0, 0.34104046242774566);'>represent</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>data</span> <span style=''>vectors</span> <span style=''>sparsely</span> <span style=''>(ie</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>(Tropp</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2006))</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>a</span> <span style=''>code</span> <span style=''>defined</span> <span style=''>by</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>basis</span> <span style=''>elements</span> <span style=''>while</span> <span style=''>also</span> <span style=''>finding</span> <span style=''>a</span> <span style=''>code</span> <span style=''>that</span> <span style=''>enables</span> <span style=''>such</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>As</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedures</span> <span style=''>for</span> <span style=''>sparse</span> <span style=''>coding</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.33962264150943394);'>theoretically</span> <span style=''>prone</span> <span style=''>to</span> <span style=''>severe</span> <span style=''>local</span> <span style=''>minima</span> <span style=''>problems</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relaxation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sparse</span> <span style=''>coding</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>boosting</span> <span style=''>style</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>(Nowozin</span> <span style=''>Bakir</span> <span style=''>2008)</span> <span style=''>serves</span> <span style=''>as</span> <span style=''>a</span> <span style=''>convex</span> <span style=''>master</span> <span style=''>problem</span> <span style=''>which</span> <span style=''>calls</span> <span style=''>a</span> <span style=''>(potentially</span> <span style=''>non</span> <span style=''>conve ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Locally</span> <span style=''>adapted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolution</span> <span style=''>based</span> <span style=''>super</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resolution</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>irregularly</span> <span style=''>sampled</span> <span style=''>ocean</span> <span style=''>remote</span> <span style=''>sensing</span> <span style=''>data</span> <br/><br/><span style=''>Super</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resolution</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>with</span> <span style=''>numerous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>to</span> <span style=''>remote</span> <span style=''>sensing</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>enhancement</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>address</span> <span style=''>the</span> <span style=''>super</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resolution</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>irregularly</span> <span style=''>sampled</span> <span style=''>remote</span> <span style=''>sensing</span> <span style=''>images</span> <span style=''>Using</span> <span style=''>an</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpolation</span> <span style=''>as</span> <span style=''>the</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resolution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>we</span> <span style=''>explore</span> <span style=''>locally</span> <span style=''>adapted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multimodal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>models</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decompositions</span> <span style=''>namely</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>(PCA)</span> <span style=''>sparse</span> <span style=''>priors</span> <span style=''>and</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>negativity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>of</span> <span style=''>sea</span> <span style=''>surface</span> <span style=''>height</span> <span style=''>(SSH)</span> <span style=''>fields</span> <span style=''>from</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>sources</span> <span style=''>along</span> <span style=''>track</span> <span style=''>altimeter</span> <span style=''>data</span> <span style=''>and</span> <span style=''>sea</span> <span style=''>surface</span> <span style='background-color:rgba(255 ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.11750088746893858)
# 	architecture (0.08590699325523607)
# 	representation (0.12850550230741925)
# 	experimental (0.136670216542421)
# 	segmentation (0.07206247781327653)
# 	information (0.25275115370962015)
# 	different (0.2598509052183174)
# 	detection (0.13276535321263755)
# 	recognition (0.1299254526091587)
# 	convolutional (0.1306354277600284)
#
# Some Statistics words are:
# 	stochastic (0.12657589510842157)
# 	estimation (0.16238023197175996)
# 	theoretical (0.1487644982349975)
# 	variables (0.14674735249621784)
# 	algorithm (0.39334341906202724)
# 	statistical (0.16086737266767523)
# 	distribution (0.1815431164901664)
# 	inference (0.18608169440242056)
# 	dimensional (0.18910741301059)
# 	regression (0.1810388300554715)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a9a592d0-21ab-4e3c-bcb3-ebfe4001c7d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9a592d0-21ab-4e3c-bcb3-ebfe4001c7d5")) {                    Plotly.newPlot(                        "a9a592d0-21ab-4e3c-bcb3-ebfe4001c7d5",                        [{"x":["persistent","established","functions","analogous","uniqueness","convergence","structure","multiresolution","stability","algorithms","construct","existence","framework","persistence","properties","clustering","functoriality","minimization","variables","polynomial","varepsilon","furthermore","representations","hypothesis","approximation","approximate","exponential","computation","approximations","restricted","consistency","estimators","including","constraint","application","processes","universal","simulations","coefficients","different","penalized","constrained","ellipsoid","estimation","autoregressive","absolutely","stationary","classification","challenging","preprocessed","recognizing","leveraging","effective","recognition","unlabeled","collection","introduce","decomposition","demonstrate","adaptation","collected","technique","convolutional","synthetic","generalization","consistence","classical","generalisation","advantage","consistent","environment","logarithmic","impossible","stochastic","confidence","sequences","intuition","generation","comparison","attributes","distribution","sequentially","generative","variational","conditional","structuring","temporally","uncertainty","generates","evolution","structured","conditioned","appearance","accounting","attribute","experimental","invariant","probabilistic","autoencoders","effectiveness","prediction","generalize","perspective","supervised","entangling","disentangle","inference","variation","interactions","multiplicative","disentangling","objective","boltzmann","regarding","information","expression","parametrized","equivalent","recurrent","recurrence","continuous","dynamical","satisfies","transformations","contribution","interfacing","topological","analytical","continuity","epistemic","presented","requirements","complexity","converges","conjecture","identifying","counterexample","probability","uniformly","approaching","attractive","efficient","regression","predictors","flexibility","developed","separately","relationship","parametric","computational","component","interpretability","scalability","challenge","combination","nonparametric","components","achieving","excellent","simultaneously","importance","simulated","algorithm","dimensions","selection","performance","interaction","decompose","knowledge","considered","promising","retrieval","optimization","propagation","viewpoint","exploited","extensively","constraints","attention","efficiently","subproblems","construction","preparation","automatically","experiments","declarative","languages","relatively","manuscript","implementation","generalizes","configuration","intervention","implement","carefully","constructing","frameworks","cumbersome","technical","differently","representative","everybody","distributed","diminishing","consensus","regularization","controlling","averaging","dirichlet","expensive","collapsed","incorporate","variations","unbounded","inappropriate","allocation","computationally","popularity","perplexity","magnitude","metropolis","documents","assignments","discovering","unwarranted","applications","posterior","parallelizable","communication","usefulness","embarrassingly","baselines","empirical","capturing","assumptions","predictive","numerically","deterministic","classication","expectation","performed","statistical","calculation","distributions","mathematical","additivity","parameters","regularizer","difficult","activations","fundamentally","potential","feedf ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	streamlined
# 	overfitted
# 	monotonically
# 	clinicians
# 	individualized
# 	selectivity
# 	prognostics
# 	omnipresent
# 	supercomputers
# 	acceptancerejection
# 	integrals
# 	eigenstructures
# 	heartbeats
# 	ultrametric
# 	colombian
# 	parallelisation
# 	reversing
# 	stationarities
# 	repeatmulti
# 	attitudes
# Some words which never appear in Statistics papers:
# 	structuring
# 	declarative
# 	transcripts
# 	recognizer
# 	superintelligent
# 	allocated
# 	displacement
# 	periphery
# 	reviewers
# 	surfacing
# 	encouraged
# 	anticipated
# 	multifaceted
# 	transmissions
# 	interfering
# 	deformations
# 	superpixels
# 	deformation
# 	superpixel
# 	diagonalizable

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.055020926893349e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7458333333333333
